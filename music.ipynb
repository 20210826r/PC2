# %%
#import sys 
#!{sys.executable} -m pip install musicbrainzngs

import musicbrainzngs

musicbrainzngs.set_useragent('pc3_grupo5', '0.1', contact=None)

artist_id = "c5c2ea1c-4bde-4f4d-bd0b-47b200bf99d6"


result = musicbrainzngs.get_artist_by_id(artist_id,
              includes=["release-groups"], release_type=["album", "ep"])
for release_group in result["artist"]["release-group-list"]:
    print("{title} ({type})".format(title=release_group["title"],
                                    type=release_group["type"]))
    
    
musicbrainzngs.search_recordings("Paramore")
# Out:
# xx (Album)
# Coexist (Album)
# I See You (Album)
# Remixes (Compilation)
# FACT Mix 70: The xx (Compilation)
# Islands (EP)
# Tour Only EP (EP)
# iTunes Live From SoHo (EP)
# iTunes Festival: London 2010 (EP)
# Innervisions Remixes (EP)
# Hivern Remixes (EP)
# Live at Club 69 (Live)
# KEXP Session (EP)
# {'recording-list': [{'id': '610aac78-0e74-4ff7-8eb9-63879d3e3e15',
#    'ext:score': '100',
#    'title': 'Paramore',
#    'length': '260000',
#    'artist-credit': [{'name': 'Mr. Ivex',
#      'artist': {'id': 'ec58eb49-533e-4a95-9da0-62729f271679',
#       'name': 'Mr. Ivex',
#       'sort-name': 'Ivex, Mr.',
#       'disambiguation': 'Frenchcore dj/producer Kevin Rikken'}},
#     ' & ',
#     {'name': 'Sghenny Madattak',
#      'artist': {'id': '835ee36d-202d-4fd8-b0b4-d3a32e563918',
#       'name': 'Sghenny Madattak',
#       'sort-name': 'Madattak, Sghenny'}}],
#    'release-list': [{'id': '1dd74a5a-4bd5-4bfb-9aa7-f11d780d88ed',
#      'title': 'LSD Problem',
#      'status': 'Official',
#      'artist-credit': [{'name': 'Mr. Ivex',
#        'artist': {'id': 'ec58eb49-533e-4a95-9da0-62729f271679',
#         'name': 'Mr. Ivex',
#         'sort-name': 'Ivex, Mr.',
#         'disambiguation': 'Frenchcore dj/producer Kevin Rikken'}},
#       ' - ',
#       {'name': 'Dr. Peacock',
#        'artist': {'id': '6d138947-ffb5-4da2-874b-9d97577f8b6c',
#         'name': 'Dr. Peacock',
#         'sort-name': 'Peacock, Dr.',
#         'disambiguation': 'frenchcore DJ'}},
#       ' & ',
#       {'name': 'Sefa',
#        'artist': {'id': 'b5416a54-4941-4fcf-b2a0-7f98da6f9344',
#         'name': 'Sefa',
#         'sort-name': 'Sefa',
#         'disambiguation': 'frenchcore artist'}}],
#      'release-group': {'id': '621a8406-4539-4eca-98b7-92b6d92c6788',
#       'type': 'EP',
#       'title': 'LSD Problem',
#       'primary-type': 'EP'},
#      'date': '2017-03-08',
#      'country': 'NL',
#      'release-event-list': [{'date': '2017-03-08',
#        'area': {'id': 'ef1b7cc0-cd26-36f4-8ea0-04d9623786c7',
#         'name': 'Netherlands',
#         'sort-name': 'Netherlands',
#         'iso-3166-1-code-list': ['NL']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '18a5c25e-cba6-4491-a2c1-027c7872acb7',
#          'number': '4',
#          'title': 'Paramore',
#          'length': '260000',
#          'track_or_recording_length': '260000'}],
#        'track-count': 4}],
#      'medium-track-count': 4,
#      'medium-count': 1,
#      'artist-credit-phrase': 'Mr. Ivex - Dr. Peacock & Sefa'}],
#    'artist-credit-phrase': 'Mr. Ivex & Sghenny Madattak'},
#   {'id': '3ac86a3a-c5cd-4ee6-a0f6-460a76898a97',
#    'ext:score': '85',
#    'title': 'Paramore Vibe',
#    'length': '183272',
#    'artist-credit': [{'name': 'The Moose',
#      'artist': {'id': '14194519-0dcd-4ea5-91c2-f0c44c3e2ed6',
#       'name': 'The Moose',
#       'sort-name': 'Moose, The',
#       'disambiguation': 'Swedish producer'}}],
#    'release-list': [{'id': 'c65846d6-27b7-4908-bce1-5d268bfa3122',
#      'title': 'Scandinavian Sound',
#      'status': 'Official',
#      'release-group': {'id': '37e0745e-8a9c-4577-bce5-3deceeb3d2e1',
#       'type': 'Album',
#       'title': 'Scandinavian Sound',
#       'primary-type': 'Album'},
#      'date': '2017',
#      'country': 'XW',
#      'release-event-list': [{'date': '2017',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '2d116341-57e1-439c-8861-22054cdb560e',
#          'number': '13',
#          'title': 'Paramore Vibe',
#          'length': '183272',
#          'track_or_recording_length': '183272'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'The Moose'},
#   {'id': 'a8eceec8-22a9-4ca0-8599-9efadfc49d27',
#    'ext:score': '75',
#    'title': 'Decode (Paramore cover)',
#    'length': '250120',
#    'artist-credit': [{'name': 'Cleaver of the Mist',
#      'artist': {'id': 'ad63ff22-3c0c-4318-8196-83daf3e861cd',
#       'name': 'Cleaver of the Mist',
#       'sort-name': 'Cleaver of the Mist'}}],
#    'release-list': [{'id': 'bf98f9ba-0234-443f-b22f-f16676727f4d',
#      'title': 'Stay Core #16',
#      'status': 'Official',
#      'artist-credit': [{'name': 'Various Artists',
#        'artist': {'id': '89ad4ac3-39f7-470e-963a-56509c546377',
#         'name': 'Various Artists',
#         'sort-name': 'Various Artists',
#         'disambiguation': 'add compilations to this artist'}}],
#      'release-group': {'id': 'e65c7c76-a7b0-48bb-9ec5-8c3381343396',
#       'type': 'EP',
#       'title': 'Stay Core #16',
#       'primary-type': 'EP',
#       'secondary-type-list': ['Compilation']},
#      'date': '2016-09-09',
#      'country': 'XW',
#      'release-event-list': [{'date': '2016-09-09',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '32ceded8-6f6a-4e00-bd39-09aebd60e541',
#          'number': '3',
#          'title': 'Decode (Paramore cover)',
#          'length': '250120',
#          'track_or_recording_length': '250120'}],
#        'track-count': 5}],
#      'medium-track-count': 5,
#      'medium-count': 1,
#      'artist-credit-phrase': 'Various Artists'}],
#    'artist-credit-phrase': 'Cleaver of the Mist'},
#   {'id': '7a541fd9-7101-47d9-b246-2b545fe0b8ae',
#    'ext:score': '75',
#    'title': "Paramore 'Misery Business'",
#    'length': '212672',
#    'artist-credit': [{'name': 'Walt Ribeiro',
#      'artist': {'id': 'ecce4724-1238-4286-8753-7ba52928cbd5',
#       'name': 'Walt Ribeiro',
#       'sort-name': 'Ribeiro, Walt'}}],
#    'release-list': [{'id': 'ab4e51e2-7424-45ab-9ac2-a8d05ecc0bba',
#      'title': 'Volume 4',
#      'status': 'Official',
#      'release-group': {'id': 'a7932f9d-ef46-4cca-83fc-c3a3cba18347',
#       'type': 'Album',
#       'title': 'Volume 4',
#       'primary-type': 'Album'},
#      'date': '2012-08-17',
#      'country': 'XW',
#      'release-event-list': [{'date': '2012-08-17',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': 'ab3fc332-dcfb-4ec6-abf3-af9cd9f7a453',
#          'number': '9',
#          'title': "Paramore 'Misery Business'",
#          'length': '212672',
#          'track_or_recording_length': '212672'}],
#        'track-count': 12}],
#      'medium-track-count': 12,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Walt Ribeiro'},
#   {'id': 'f5282284-27fb-4b3a-a55c-6810c2741f01',
#    'ext:score': '75',
#    'title': 'Paramore ‘Misery Business’',
#    'length': '212000',
#    'artist-credit': [{'name': 'Walt Ribeiro',
#      'artist': {'id': 'ecce4724-1238-4286-8753-7ba52928cbd5',
#       'name': 'Walt Ribeiro',
#       'sort-name': 'Ribeiro, Walt'}}],
#    'release-list': [{'id': '06a48973-74c4-4a0b-a227-35cb0ad1f5a8',
#      'title': 'Every Song!',
#      'status': 'Official',
#      'release-group': {'id': '0a5c30a0-5e4e-4c00-85da-66a139f6e907',
#       'type': 'Compilation',
#       'title': 'Every Song!',
#       'primary-type': 'Album',
#       'secondary-type-list': ['Compilation']},
#      'date': '2014-11-11',
#      'country': 'US',
#      'release-event-list': [{'date': '2014-11-11',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '3851d269-df58-4d45-9885-0a7eabffdec7',
#          'number': '97',
#          'title': 'Paramore ‘Misery Business’',
#          'length': '212000',
#          'track_or_recording_length': '212000'}],
#        'track-count': 145}],
#      'medium-track-count': 145,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Walt Ribeiro'},
#   {'id': '85af3ff9-01a7-4419-8971-1abe869663f3',
#    'ext:score': '75',
#    'title': 'Ignorance (Paramore Cover)',
#    'length': '213280',
#    'artist-credit': [{'name': 'Dawn of the Maya',
#      'artist': {'id': '4535fdc0-e63a-4cef-9906-d2557c997d18',
#       'name': 'Dawn of the Maya',
#       'sort-name': 'Dawn of the Maya',
#       'alias-list': [{'sort-name': 'DOTM',
#         'type': 'Artist name',
#         'alias': 'DOTM'}]}}],
#    'release-list': [{'id': '54c9b5db-ac93-42dc-90e3-7e732e29070f',
#      'title': 'The Truth Is In Front Of You - Deluxe Edition',
#      'status': 'Official',
#      'artist-credit': [{'name': 'Dawn of the Maya',
#        'artist': {'id': '4535fdc0-e63a-4cef-9906-d2557c997d18',
#         'name': 'Dawn of the Maya',
#         'sort-name': 'Dawn of the Maya'}}],
#      'release-group': {'id': 'd83afee8-f90c-4c16-a751-3d297cbd72dc',
#       'type': 'Album',
#       'title': 'The Truth Is In Front Of You - Deluxe Edition',
#       'primary-type': 'Album'},
#      'date': '2014-05-20',
#      'country': 'ES',
#      'release-event-list': [{'date': '2014-05-20',
#        'area': {'id': '471c46a7-afc5-31c4-923c-d0444f5053a4',
#         'name': 'Spain',
#         'sort-name': 'Spain',
#         'iso-3166-1-code-list': ['ES']}}],
#      'medium-list': [{'position': '1',
#        'track-list': [{'id': 'a83dc2bb-651e-4449-b35c-2cd598e8e340',
#          'number': '18',
#          'title': 'Ignorance (Paramore Cover)',
#          'length': '213280',
#          'track_or_recording_length': '213280'}],
#        'track-count': 18}],
#      'medium-track-count': 18,
#      'medium-count': 1,
#      'artist-credit-phrase': 'Dawn of the Maya'}],
#    'artist-credit-phrase': 'Dawn of the Maya'},
#   {'id': '49f9feec-18b4-4053-b02b-a55e97ddaff6',
#    'ext:score': '75',
#    'title': 'Decode (Paramore Cover)',
#    'length': '257000',
#    'artist-credit': [{'name': 'Cole Rolland',
#      'artist': {'id': '07342982-6c91-4fe4-9a29-7b37d36efdb9',
#       'name': 'Cole Rolland',
#       'sort-name': 'Rolland, Cole'}},
#     ' feat. ',
#     {'name': 'Lauren Babic',
#      'artist': {'id': 'a65980eb-3592-40ac-ae08-dc1fde8e3364',
#       'name': 'Lauren Babic',
#       'sort-name': 'Babic, Lauren'}}],
#    'release-list': [{'id': '16ac2e87-d463-4c0e-94d4-02a6a5b311d9',
#      'title': 'Decode',
#      'status': 'Official',
#      'artist-credit': [{'name': 'Cole Rolland',
#        'artist': {'id': '07342982-6c91-4fe4-9a29-7b37d36efdb9',
#         'name': 'Cole Rolland',
#         'sort-name': 'Rolland, Cole'}}],
#      'release-group': {'id': 'c35bcfcd-fa3a-4731-adeb-1c1f45b21149',
#       'type': 'Single',
#       'title': 'Decode',
#       'primary-type': 'Single'},
#      'date': '2017',
#      'country': 'XW',
#      'release-event-list': [{'date': '2017',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '6afcbcc5-6073-42b7-9ced-e60c381cf237',
#          'number': '1',
#          'title': 'Decode (Paramore Cover)',
#          'length': '257000',
#          'track_or_recording_length': '257000'}],
#        'track-count': 1}],
#      'medium-track-count': 1,
#      'medium-count': 1,
#      'artist-credit-phrase': 'Cole Rolland'}],
#    'artist-credit-phrase': 'Cole Rolland feat. Lauren Babic'},
#   {'id': 'ea9dc07c-0fe8-48e8-8b6c-39f1faf8b154',
#    'ext:score': '75',
#    'title': 'Evolution of Paramore',
#    'length': '332000',
#    'artist-credit': [{'name': 'Halocene',
#      'artist': {'id': '536a63a4-0d31-46d3-932c-d9b25e30ea97',
#       'name': 'Halocene',
#       'sort-name': 'Halocene'}},
#     ', ',
#     {'name': 'Terabrite',
#      'artist': {'id': '048c9710-e461-47c7-842f-90deee922c84',
#       'name': 'TeraBrite',
#       'sort-name': 'TeraBrite'}},
#     ', ',
#     {'name': 'First to Eleven',
#      'artist': {'id': '7b9ab1b7-7cef-4965-bad7-9f119ce8b6ff',
#       'name': 'First to Eleven',
#       'sort-name': 'First to Eleven',
#       'alias-list': [{'sort-name': 'F211',
#         'type': 'Search hint',
#         'alias': 'F211'},
#        {'sort-name': 'First 2 Eleven',
#         'type': 'Artist name',
#         'alias': 'First 2 Eleven'}]}}],
#    'release-list': [{'id': '24491947-b045-4101-8246-4fb25c264803',
#      'title': "We've Got It Covered, Vol. 4",
#      'status': 'Official',
#      'disambiguation': 'Digital Download version',
#      'artist-credit': [{'name': 'Halocene',
#        'artist': {'id': '536a63a4-0d31-46d3-932c-d9b25e30ea97',
#         'name': 'Halocene',
#         'sort-name': 'Halocene'}}],
#      'release-group': {'id': 'edd5887e-6524-4b62-bbc4-3336b755a5d0',
#       'type': 'Album',
#       'title': "We've Got It Covered, Vol. 4",
#       'primary-type': 'Album'},
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': 'b3207b44-b3b6-410d-be75-07c0be9ec43c',
#          'number': '7',
#          'title': 'Evolution of Paramore',
#          'length': '332000',
#          'track_or_recording_length': '332000'}],
#        'track-count': 24}],
#      'medium-track-count': 24,
#      'medium-count': 1,
#      'artist-credit-phrase': 'Halocene'}],
#    'artist-credit-phrase': 'Halocene, Terabrite, First to Eleven'},
#   {'id': '7427435c-a529-4de8-bf2a-88877b3514b5',
#    'ext:score': '67',
#    'title': 'Misery Business (Paramore remix)',
#    'length': '176000',
#    'artist-credit': [{'name': 'The Age of Rockets',
#      'artist': {'id': '81c57018-28ea-4c19-b3f5-116a035da9c6',
#       'name': 'The Age of Rockets',
#       'sort-name': 'Age of Rockets, The'}}],
#    'release-list': [{'id': '52a962c8-5b47-483c-908f-6cc0bc7cf25b',
#      'title': 'Free Songs',
#      'status': 'Official',
#      'release-group': {'id': '9f6b4e53-b4c4-46d8-ae8a-2c195e5909f2',
#       'type': 'Compilation',
#       'title': 'Free Songs',
#       'primary-type': 'Album',
#       'secondary-type-list': ['Compilation']},
#      'date': '2010-01-01',
#      'country': 'US',
#      'release-event-list': [{'date': '2010-01-01',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': 'f440e1af-b0ab-348f-ade4-8573242af32e',
#          'number': '3',
#          'title': 'Misery Business (Paramore remix)',
#          'length': '176000',
#          'track_or_recording_length': '176000'}],
#        'track-count': 8}],
#      'medium-track-count': 8,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'The Age of Rockets'},
#   {'id': 'ccee2d05-701a-40ff-ba5f-1e9121cb1dd3',
#    'ext:score': '67',
#    'title': 'Brick Halo (Paramore/Beyonce)',
#    'length': '289000',
#    'artist-credit': [{'name': 'DJ Schmolli',
#      'artist': {'id': '13d2e4d7-f439-4119-bc59-bb590fc6573a',
#       'name': 'DJ Schmolli',
#       'sort-name': 'Schmolli, DJ'}}],
#    'release-list': [{'id': '68af802a-e665-40ca-985a-2bd64b9ff562',
#      'title': 'Mashupocalypse – More Essentials',
#      'status': 'Official',
#      'release-group': {'id': 'bc400f52-789c-4e0c-99d6-bfe7fb1061e6',
#       'type': 'Compilation',
#       'title': 'Mashupocalypse – More Essentials',
#       'primary-type': 'Album',
#       'secondary-type-list': ['Compilation']},
#      'date': '2012',
#      'country': 'XW',
#      'release-event-list': [{'date': '2012',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '2',
#        'format': 'Digital Media',
#        'track-list': [{'id': '73501866-074e-4826-b805-d67ea29e75f3',
#          'number': '10',
#          'title': 'Brick Halo',
#          'length': '289000',
#          'track_or_recording_length': '289000'}],
#        'track-count': 21}],
#      'medium-track-count': 41,
#      'medium-count': 2},
#     {'id': 'efc0d219-7ad5-45e9-81d3-2953da03d62f',
#      'title': 'Schnipseljagd Vol.9',
#      'status': 'Official',
#      'release-group': {'id': '9107e3e8-33ed-4aed-85a6-4debdb45e469',
#       'type': 'Album',
#       'title': 'Schnipseljagd Vol.9',
#       'primary-type': 'Album'},
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': 'abdfed28-597f-42e0-8800-c5641c5e2810',
#          'number': '17',
#          'title': 'Brick Halo',
#          'length': '289000',
#          'track_or_recording_length': '289000'}],
#        'track-count': 22}],
#      'medium-track-count': 22,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'DJ Schmolli'},
#   {'id': 'bff38976-f673-491c-b073-e57173d73113',
#    'ext:score': '67',
#    'title': 'Decode (Paramore String Tribute)',
#    'length': '232080',
#    'artist-credit': [{'name': 'String Tribute Players',
#      'artist': {'id': '9318b15a-7b97-4594-a93c-64bd7c2a6b14',
#       'name': 'String Tribute Players',
#       'sort-name': 'String Tribute Players'}}],
#    'release-list': [{'id': 'db6a578e-be51-4454-95ee-27ce7dc8afc1',
#      'title': 'String Tribute to Twilight: Original Motion Picture Soundtrack',
#      'status': 'Official',
#      'disambiguation': 'front cover has “STRING TRIBUTE” in one line, forest and full moon as background, trees in front of moon not brighter',
#      'release-group': {'id': 'e83055b8-aa8a-4732-b760-83dc1bc02eb0',
#       'type': 'Soundtrack',
#       'title': 'String Tribute to Twilight: Original Motion Picture Soundtrack',
#       'primary-type': 'Album',
#       'secondary-type-list': ['Soundtrack']},
#      'date': '2009',
#      'country': 'US',
#      'release-event-list': [{'date': '2009',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'a49e7114-d8b6-4d28-a95e-b1d8ab40b1f6',
#          'number': '3',
#          'title': 'Decode (Paramore String Tribute)',
#          'length': '232080',
#          'track_or_recording_length': '232080'}],
#        'track-count': 10}],
#      'medium-track-count': 10,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'String Tribute Players'},
#   {'id': 'a014916b-efdf-4fbe-b25a-d4a8c74290b3',
#    'ext:score': '67',
#    'title': 'Paramore Still Fucking Suck',
#    'length': '224767',
#    'artist-credit': [{'name': 'King Medicine',
#      'artist': {'id': 'ab4424a7-c306-490b-ab0f-871be88c19b1',
#       'name': 'King Medicine',
#       'sort-name': 'King Medicine'}}],
#    'release-list': [{'id': '93b75676-0bd2-460d-bd99-b3952f4e4592',
#      'title': 'King Sad',
#      'status': 'Official',
#      'release-group': {'id': 'f14b5f9b-3b8c-4bd1-8c4e-29bd859d3708',
#       'type': 'Album',
#       'title': 'King Sad',
#       'primary-type': 'Album'},
#      'date': '2013-03-21',
#      'country': 'XW',
#      'release-event-list': [{'date': '2013-03-21',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': 'e3e1b0cc-7c51-47be-bae2-72d966a73c85',
#          'number': '8',
#          'title': 'Paramore Still Fucking Suck',
#          'length': '224767',
#          'track_or_recording_length': '224767'}],
#        'track-count': 14}],
#      'medium-track-count': 14,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'King Medicine'},
#   {'id': 'e1032968-026f-4ca0-b17c-f8d75df60705',
#    'ext:score': '67',
#    'title': 'Paramore - Decode (Cover)',
#    'length': '257000',
#    'video': 'true',
#    'artist-credit': [{'name': 'Dani Skylar',
#      'artist': {'id': '53615df5-7b3a-45a8-84f1-594a27b038e0',
#       'name': 'Dani Skylar',
#       'sort-name': 'Skylar, Dani'}}],
#    'release-list': [{'id': '6e3491b0-0838-4e65-92c9-b8795f0e273c',
#      'title': 'Paramore - Decode (Cover) by Dani Skylar',
#      'status': 'Official',
#      'release-group': {'id': '62126ac9-0078-4506-b998-51477cd02d5b',
#       'type': 'Single',
#       'title': 'Paramore - Decode (Cover) by Dani Skylar',
#       'primary-type': 'Single'},
#      'date': '2020-05-16',
#      'country': 'US',
#      'release-event-list': [{'date': '2020-05-16',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '8f8edbb9-5150-449b-b36c-febea3c17a11',
#          'number': '1',
#          'title': 'Paramore - Decode (Cover)',
#          'length': '257000',
#          'track_or_recording_length': '257000'}],
#        'track-count': 1}],
#      'medium-track-count': 1,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Dani Skylar'},
#   {'id': '486e7562-63eb-49d8-9432-b87b256d8e8a',
#    'ext:score': '67',
#    'title': 'Fun (Kygo vs. Paramore)',
#    'length': '288000',
#    'artist-credit': [{'name': 'Smija',
#      'artist': {'id': '2b44f301-037d-4810-8600-cee27aed111d',
#       'name': 'Smija',
#       'sort-name': 'Smija'}}],
#    'release-list': [{'id': 'bdeacf17-7ef4-4daf-b1a9-6d85c45998ac',
#      'title': 'Mash‐Up Your Bootz Party Sampler Vol. 94',
#      'status': 'Official',
#      'artist-credit': [{'name': 'DJ Morgoth',
#        'artist': {'id': '77af0cd3-69b0-4982-bcf4-255b3fbaae10',
#         'name': 'DJ Morgoth',
#         'sort-name': 'Morgoth, DJ'}}],
#      'release-group': {'id': 'e59b9886-cd1b-45fa-84b6-845d236586cf',
#       'type': 'Compilation',
#       'title': 'Mash‐Up Your Bootz Party Sampler Vol. 94',
#       'primary-type': 'Album',
#       'secondary-type-list': ['Compilation']},
#      'date': '2015-03-30',
#      'country': 'XW',
#      'release-event-list': [{'date': '2015-03-30',
#        'area': {'id': '525d4e18-3d00-31b9-a58b-a146a916de8f',
#         'name': '[Worldwide]',
#         'sort-name': '[Worldwide]',
#         'iso-3166-1-code-list': ['XW']}}],
#      'medium-list': [{'position': '1',
#        'format': 'Digital Media',
#        'track-list': [{'id': '4e1135a8-a5d7-42ba-ba4e-d6b8ec14339a',
#          'number': '5',
#          'title': 'Fun',
#          'length': '288000',
#          'track_or_recording_length': '288000'}],
#        'track-count': 17}],
#      'medium-track-count': 17,
#      'medium-count': 1,
#      'artist-credit-phrase': 'DJ Morgoth'}],
#    'artist-credit-phrase': 'Smija'},
#   {'id': '0dad078d-4373-409b-8a89-e8d4303418ee',
#    'ext:score': '62',
#    'title': 'Saturday',
#    'length': '147266',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'a4a55de1-8529-3af1-b860-b1fb8382b0de',
#          'number': '5',
#          'title': 'Saturday',
#          'length': '147266',
#          'track_or_recording_length': '147266'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '3b0fe0dd-849d-46f0-843b-45d13830038a',
#    'ext:score': '62',
#    'title': 'Alibi',
#    'length': '176533',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'dabb010e-f63d-3806-92ae-03f4daec69e3',
#          'number': '2',
#          'title': 'Alibi',
#          'length': '176533',
#          'track_or_recording_length': '176533'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': 'd1ea856c-6c1e-44b8-a11c-3a6dcc993590',
#    'ext:score': '62',
#    'title': 'Feel Okay',
#    'length': '130160',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': '85362f64-57da-3dcd-bfa8-46ec46622830',
#          'number': '7',
#          'title': 'Feel Okay',
#          'length': '130160',
#          'track_or_recording_length': '130160'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '994ac211-3433-469d-9c12-3eee60965da6',
#    'ext:score': '62',
#    'title': 'Falling Away',
#    'length': '163026',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'e1c28422-6c94-34b3-8233-b8800aac2290',
#          'number': '8',
#          'title': 'Falling Away',
#          'length': '163026',
#          'track_or_recording_length': '163026'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '8d65fd98-2d6a-4d1f-b3da-f57f54d47b9f',
#    'ext:score': '62',
#    'title': 'Only One',
#    'length': '170454',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': '403a8f7f-21b0-3e7b-8c46-570b8b24ce6e',
#          'number': '15',
#          'title': 'Only One',
#          'length': '170454',
#          'track_or_recording_length': '170454'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '818ecbe7-dc28-4290-8314-db6dce94f2ad',
#    'ext:score': '62',
#    'title': 'Asleep All Day',
#    'length': '163426',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': '06159024-7313-36e3-b1c6-b00d12ffe247',
#          'number': '1',
#          'title': 'Asleep All Day',
#          'length': '163426',
#          'track_or_recording_length': '163426'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': 'b9718afb-e8da-45ac-a75f-48703871f8aa',
#    'ext:score': '62',
#    'title': 'There You Go (Here I Come)',
#    'length': '174800',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': '6be7a0b4-a765-3035-8826-fa019cbabc79',
#          'number': '4',
#          'title': 'There You Go (Here I Come)',
#          'length': '174800',
#          'track_or_recording_length': '174800'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '57e647db-ae6f-41e1-9224-4b046aa51659',
#    'ext:score': '62',
#    'title': 'What You Don’t Know',
#    'length': '161800',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': '63068b55-a6eb-301f-99d0-b195b499f333',
#          'number': '9',
#          'title': 'What You Don’t Know',
#          'length': '161800',
#          'track_or_recording_length': '161800'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '2d6c1dc1-0568-44c8-8ac2-c73f4477a716',
#    'ext:score': '62',
#    'title': 'Seasons',
#    'length': '120760',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'd83fddeb-081b-309b-98a8-2cef1cd06054',
#          'number': '12',
#          'title': 'Seasons',
#          'length': '120760',
#          'track_or_recording_length': '120760'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '55c0c089-a074-4a13-b6a4-924fd7c73eb7',
#    'ext:score': '62',
#    'title': 'Basement June',
#    'length': '243680',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'c2ee4ee8-4a15-3be9-8720-77abf3469e82',
#          'number': '14',
#          'title': 'Basement June',
#          'length': '243680',
#          'track_or_recording_length': '243680'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'},
#   {'id': '04dab652-8ab6-4ea8-97c9-8b2706ff1c85',
#    'ext:score': '62',
#    'title': 'Amaze Me',
#    'length': '177080',
#    'artist-credit': [{'name': 'Paramore',
#      'artist': {'id': '728ea90d-279b-4201-a8c4-597830883150',
#       'name': 'Paramore',
#       'sort-name': 'Paramore',
#       'disambiguation': 'indie duo, active 1999-2002'}}],
#    'release-list': [{'id': '355ddc9c-a723-450c-8318-d86baf561cfb',
#      'title': 'What You Don’t Know',
#      'status': 'Official',
#      'release-group': {'id': 'f8a9721c-f60a-34df-882b-1b643d082032',
#       'type': 'Album',
#       'title': 'What You Don’t Know',
#       'primary-type': 'Album'},
#      'date': '2001',
#      'country': 'US',
#      'release-event-list': [{'date': '2001',
#        'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#         'name': 'United States',
#         'sort-name': 'United States',
#         'iso-3166-1-code-list': ['US']}}],
#      'medium-list': [{'position': '1',
#        'format': 'CD',
#        'track-list': [{'id': 'de274ef0-720a-3f2f-a3c5-770d0706bb94',
#          'number': '3',
#          'title': 'Amaze Me',
#          'length': '177080',
#          'track_or_recording_length': '177080'}],
#        'track-count': 15}],
#      'medium-track-count': 15,
#      'medium-count': 1}],
#    'artist-credit-phrase': 'Paramore'}],
#  'recording-count': 547}
